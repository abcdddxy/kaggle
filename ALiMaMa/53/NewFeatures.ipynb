# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt
# import seaborn as sns
# import pickle
import time
from tqdm import tqdm

# %matplotlib inline

#每次可以输出多个变量
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from pylab import rcParams
rcParams['figure.figsize'] = 14, 6

import warnings
warnings.filterwarnings("ignore")

#中文字体
import matplotlib
matplotlib.use('qt4agg')
#指定默认字体
matplotlib.rcParams['font.sans-serif'] = ['SimHei']
matplotlib.rcParams['font.family'] = 'sans-serif'
#解决负号'-'显示为方块的问题
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
train = pd.read_csv('train_new_features.csv')
val = pd.read_csv('val_new_features.csv')
test = pd.read_csv('test_new_features.csv')

train.shape
val.shape
test.shape
# Out:
# (203112, 583)
# (57411, 583)
# (18371, 583)

# %%
predictors = ['user_query_percent1_city_hot',
 'city_trade_hot',
 'user_query_max2_item_score3',
 'item_id_pred_1',
 'shop_review_num_level+shop_item_cnt_pred_1',
 'item_brand_id+item_price_level_pred_1',
 'shop_current_hour_query',
 'item_city_id+context_page_id_pred_1',
 'item_city_sales_div_pv_category_percent',
 'item_cat_vec_4',
 'user_query_min2_instance_id',
 'user_query_min1_user_sell_power_mean_item_minus',
 'brand_hot',
 'item_cnt_dayavg_total',
 'pred_cat_mean_22',
 'shop_id',
 'shop_score_service',
 'item_brand_id_user_gender_id_percent',
 'user_query_min1_user_sell_trade_power_mean_item_minus',
 'user_context_trade_count',
 'item_city_sales_div_pv_category_rank',
 'pred_property_split_count',
 'query_col_10',
 'user_context_count',
 'category_col_11',
 'user_item_last_time_sub',
 'user_current_hour_query',
 'user_query_max2_occupation_hot',
 'user_age_level_isnew',
 'item_is_his',
 'user_query_percent1_user_sell_power_mean_item_minus',
 '24h_user_seem_times_pred_1',
 'item_cat_vec_19',
 'shop_cnt_dayavg_total',
 'user_query_maxsell',
 'shop_cnt_day',
 'shop_current_hour_percent',
 'star_property_var',
 'user_query_max_score5',
 'query_col_1',
 'user_query_percent1_item_score',
 'user_isnew',
 'sale_price',
 'user_query_percent2_item_score3',
 'user_brand_count',
 'shop_cnt_total',
 'pred_cat_mean_1',
 'shop_review_num_level',
 'user_day_count',
 'pred_cat_mean_12',
 'pred_cat_mean_4',
 'item_id',
 'item_sales_level+item_pv_level_pred_1',
 'item_cnt_total',
 'pred_cat_mean_20',
 'user_query_cheapest',
 'shop_item_cnt',
 'user_query_percent1_instance_id',
 'star_category_max',
 'query_category_0',
 'user_query_maxpv',
 'common_category_prob2',
 'user_query_rank2_city_hot',
 'user_query_percent2_city_hot',
 'user_query_goodreview_percent',
 'user_star_level',
 'shop_today_query_percent',
 'user_query_max_score3_rank',
 'shop_review_positive_rate',
 'user_query_rank2_user_sell_trade_power_mean_item_minus',
 'item_cat_vec_15',
 'user_hour_count',
 'pred_cat_mean_14',
 'is_last_user_item_click',
 'item_brand_sales_category_percent',
 'pred_cat_mean_17',
 'user_query_max2_brand_hot',
 'user_query_percent2_instance_id',
 'user_query_rank1_item_score2',
 'item_hot',
 'user_query_sales_div_pv_percent',
 'user_hour_query',
 'user_query_rank2_item_score3',
 'city_item_count',
 'user_item_age_dist',
 'user_query_min2_idx',
 'user_sell_power',
 'item_today_query_percent',
 'user_query_rank1_occupation_hot',
 'user_query_rank2_brand_hot',
 'user_query_maxqueryitem_c_similarity2',
 'user_query_max_score6_percent',
 'item_cat_vec_6',
 'item_cat_vec_10',
 'user_query_max2_shop_score',
 'item_pred_property_score',
 'item_city_sales_category_percent',
 'category_col_15',
 'user_item_hour_query',
 'user_age_level+user_star_level_pred_1',
 'user_query_rank1_item_trade_hot',
 'query_col_6',
 'user_query_max_score3_percent',
 'common_category',
 'city_hot',
 'user_query_max2_item_hot',
 'query_col_9',
 'shop_id_pred_1',
 'mins',
 'item_id+hist_hour_ctr_pred_1',
 'shop_avg_star',
 'user_query_percent2_24h_ppt_hot',
 'query_col_4',
 'item_pv_level+shop_review_positive_rate_pred_1',
 'property_4',
 'user_sell_trade_power',
 'shop_id_isnew',
 'user_query_max1_item_score2',
 'user_query_max_score9_percent',
 'item_id_isnew',
 'shop_item_count',
 'user_query_queryitem_p_similarity_rank',
 'item_cat_vec_9',
 'user_query_max_score7_percent',
 'city_brand_count',
 'item_brand_id+star_property_max_pred_1',
 'pred_cat_mean_2',
 'user_query_max_score9',
 'item_city_pv_category_percent',
 'user_query_max_score3',
 'user_hot',
 'user_shop_num',
 'common_category_prob',
 'user_query_price_percent',
 'property_3',
 'query_category_3',
 'user_query_max1_shop_hot',
 'occupation_trade_percent',
 'hour',
 'user_query_pv_rank',
 'item_cat_vec_7',
 'item_pred_property_score_item%',
 'time_slice',
 'pred_cat_mean_0',
 'item_cat_vec_16',
 'property_2',
 'user_query_delivery_percent',
 'user_query_max_score5_rank',
 'item_cat_vec_0',
 'category_count',
 'user_query_percent1_item_hot',
 'is_last_click',
 'pred_cat_mean_6',
 'user_query_rank2_instance_id',
 'item_brand_sales_category_rank',
 'star_category_var',
 'user_count_first_time_sub',
 'item_city_collect_category_percent',
 'user_shop_count',
 'user_query_percent2_brand_hot',
 'user_query_percent1_user_hot',
 'user_query_maxshopstar',
 'user_query_max_score2_rank',
 'user_query_best_delivery',
 'query_col_11',
 'item_pv_stair',
 'query_category_4',
 'user_item_star_dist',
 'user_query_max_score1',
 'shop_item_cnt+shop_brand_cnt_pred_1',
 'category_col_12',
 'user_query_min2_user_sell_trade_power_mean_item_minus',
 'user_query_percent2_item_score2',
 'user_day_query',
 'user_brand_trade_count',
 'yesterhour',
 'user_occupation_id',
 'user_minute_count',
 'yesterday',
 'item_cat_vec_21',
 'item_cat_vec_11',
 'pred_cat_mean_3',
 'user_item_count_first_time_sub',
 'user_item_next_time_sub',
 'user_query_rank2_shop_score',
 'user_trade_hot',
 'item_collect_category_rank',
 'item_cat_vec_1',
 'item_cat_vec_3',
 'user_query_max_score1_rank',
 'shop_item_cnt+star_property_var_pred_1',
 'user_sell_power_mean_item_minus',
 'pred_cat_mean_23',
 'user_query_max1_shop_score',
 'user_gender_id+star_category_min_pred_1',
 'item_brand_id+shop_brand_cnt_pred_1',
 'user_occupation_stair',
 'property_6',
 'user_query_queryitem_p_similarity_percent2',
 'item_cat_vec_5',
 'star_property_max',
 'user_query_rank2_user_hot',
 'brand_today_query',
 'sale_collect',
 'item_cat_vec_2',
 'user_query_percent2_item_trade_hot',
 'item_brand_pv_category_percent',
 'user_query_percent1_shop_hot',
 'user_count',
 'item_price_level_pred_1',
 'pred_cat_mean_5',
 'user_query_rank2_item_score',
 'item_city_price_category_percent',
 'item_brand_collect_category_percent',
 'user_query_percent1_user_sell_trade_power_mean_item_minus',
 'item_score2',
 'user_query_percent2_shop_score',
 'shop_trade_hot',
 'user_query_rank1_24h_ppt_hot',
 'item_brand_sales_div_pv_category_rank',
 'item_city_collect_category_rank',
 'user_gender_id',
 'user_query_times',
 'item_pv_category_rank',
 'user_query_max_score4',
 'max_click_time_sub',
 'next_time_sub',
 'pred_cat_mean_18',
 'pred_cat_mean_16',
 'user_query_max2_item_trade_hot',
 'minute',
 'common_property',
 'item_city_sales_category_rank',
 'user_occupation_id_isnew',
 'query_col_2',
 'item_pv_category_percent',
 'brand_avg_age',
 'item_city_id_idx',
 'property_0',
 'user_query_delivery_rank',
 'item_brand_id_user_occupation_id_percent',
 'user_query_max_score7_rank',
 'user_query_max2_shop_hot',
 'category_col_3',
 'pred_cat_mean_13',
 'item_cat_vec_14',
 'user_query_maxqueryitem_p_similarity',
 'user_item_num',
 'user_star_level+shop_id_pred_1',
 'user_query_rank2_idx',
 'user_query_rank1_item_score3',
 'is_home',
 'item_cat_vec_17',
 'pred_cat_mean_21',
 'user_query_maxqueryitem_c_similarity',
 'query_col_12',
 'common_property_prob2',
 'user_query_service_percent',
 'user_query_percent2_item_score',
 'user_query_goodreview_rank',
 'item_avg_age',
 'query_col_8',
 'property_7',
 'user_query_percent2_user_sell_trade_power_mean_item_minus',
 'user_query_description_rank',
 '24h_user_seem_times',
 'brand_is_trade_his',
 'user_query_review_percent',
 'user_query_max2_item_score',
 'item_sales_category_rank',
 'user_today_query_percent',
 'user_query_max2_item_score2',
 'query_category_2',
 'brand_item_count_his',
 'user_query_queryitem_p_similarity_rank2',
 'category_col_1',
 'item_collected_level+user_gender_id_pred_1',
 'category_col_8',
 'user_item_day_num',
 'user_query_rank2_item_hot',
 'context_timestamp',
 'item_pred_category_score_item%',
 'item_collect_div_pv',
 'item_brand_id_user_age_level_percent',
 'category_col_7',
 'query_category_5',
 'user_age_level+user_id_pred_1',
 'user_query_review_rank',
 'user_current_hour_percent',
 'user_query_percent1_24h_ppt_hot',
 'user_query_max_score2_percent',
 'item_id_user_gender_id_percent',
 'user_shop_last_time_sub',
 'common_property_prob',
 'brand_current_hour_query',
 'item_cnt_day',
 'city_brand_count_his',
 'user_query_collect_percent',
 'user_shop_day_num',
 'user_query_sale_rank',
 'shop_score_delivery',
 'query_col_3',
 'user_query_queryitem_c_similarity_rank2',
 'user_query_percent2_user_sell_power_mean_item_minus',
 'item_price_level',
 'category_2',
 'user_query_min2_user_sell_power_mean_item_minus',
 'category_col_5',
 'user_query_max1_24h_cat_hot',
 'query_col_7',
 'item_cat_vec_13',
 'item_sales_div_pv_percent',
 'shop_score',
 'user_query_percent2_occupation_hot',
 'user_sell_power_mean',
 'item_current_hour_percent',
 'occupation_hot',
 'item_cat_vec_20',
 'item_brand_pv_category_rank',
 'user_query_rank2_item_score2',
 'property_5',
 'user_query_max_score8_rank',
 'brand_today_query_percent',
 'pred_cat_mean_10',
 'user_query_percent1_item_trade_hot',
 'property_8',
 'item_brand_sales_div_pv_category_percent',
 'pred_cat_mean_15',
 'category_col_2',
 'user_query_rank2_occupation_hot',
 'user_item_trade_count',
 'item_property_split_count',
 'user_firstquery_timedelta',
 'city_item_count_his',
 'user_query_max_score10_percent',
 'occupation_trade_hot',
 'item_brand_id',
 'gender_age',
 'user_query_rank2_24h_ppt_hot',
 'user_minute_query',
 'item_brand_id_isnew',
 'category_col_14',
 'category_col_9',
 'pred_cat_mean_9',
 'user_query_best_service',
 'user_query_maxsales_div_pv',
 'gender_filled',
 'item_price_level+item_pred_cat_cos_pred_1',
 'category_col_13',
 'user_lastquery_timedelta',
 'item_price_stair',
 'pred_cat_mean_19',
 'item_trade_percent',
 'item_minute_query',
 '24h_cat_hot',
 'user_query_rank1_shop_score',
 'user_query_queryitem_p_similarity_percent',
 'item_sales_category_percent',
 'user_query_max1_item_score3',
 'user_is_his',
 'user_query_max_score1_percent',
 'item_cat_vec_22',
 'item_is_trade_his',
 'user_query_max2_user_hot',
 'user_query_max1_instance_id',
 'shop_star_level+shop_item_cnt_pred_1',
 'user_query_rank2_shop_hot',
 'item_collected_level+shop_score_description_pred_1',
 'user_query_percent1_item_score2',
 'user_query_percent2_item_hot',
 'max_user_item_click_time_sub',
 'shop_score_description',
 'item_id_user_star_level_percent',
 'user_cnt_day',
 'item_collected_stair',
 'user_query_percent1_occupation_hot',
 'item_city_pv_category_rank',
 'brand_is_his',
 '24h_ppt_hot',
 'user_query_rank1_city_hot',
 'item_pv_level',
 'user_query_percent1_24h_cat_hot',
 'item_sales_div_pv_rank',
 'user_item_minute_query',
 'context_page_id',
 'user_query_maxqueryitem_p_similarity2',
 'item_brand_price_category_rank',
 'item_pred_property_score_pred%',
 'item_cat_vec_8',
 'user_query_max1_brand_hot',
 'star_property_min',
 'user_query_description_percent',
 'star_property_mean',
 'item_sales_level+item_collected_level_pred_1',
 'item_collected_level+item_id_pred_1',
 'item_brand_price_category_percent',
 'user_query_max1_occupation_hot',
 'user_query_maxgoodreview',
 'day',
 'category_1',
 'item_sales_div_pv',
 'pred_category_split_count',
 'user_query_min1_idx',
 'user_query_max_score4_rank',
 'user_query_maxreview',
 'user_id',
 'user_shop_trade_count',
 'pred_cat_mean_7',
 'item_brand_id+hist_hour_ctr_pred_1',
 'item_city_price_category_rank',
 'item_brand_id+shop_score_description_pred_1',
 'item_brand_collect_category_rank',
 'item_city_id_isnew',
 'user_brand_age_dist',
 'shop_id_user_star_level_percent',
 'user_query_queryitem_c_similarity_percent2',
 'user_query_rank1_user_sell_trade_power_mean_item_minus',
 'user_query_max_score2',
 'user_query_max1_city_hot',
 'user_item_count',
 'user_query_shopstar_rank',
 'hour_stair',
 'last_time_sub',
 'user_cnt_total',
 'user_shop_next_time_sub',
 'user_query_max2_24h_ppt_hot',
 'shop_today_query',
 'item_occupation_trade_count',
 'item_cat_vec_18',
 'shop_review_num_level+hist_hour_ctr_pred_1',
 'shop_hot',
 'user_query_max_score5_percent',
 'user_query_max2_24h_cat_hot',
 'user_yesterday_query',
 'pred_cat_mean_11',
 'shop_star_level',
 'user_shop_count_first_time_sub',
 'user_is_trade_his',
 'shop_brand_cnt',
 'item_cat_vec_23',
 'star_category_min',
 'user_total_query_times',
 'item_cat_vec_12',
 'user_sell_trade_power_mean_item_minus',
 'pred_cat_mean_8',
 'item_category_split_count',
 'review_star',
 'user_query_rank1_idx',
 'item_pred_category_score',
 'category_col_6']

# %%
import sys
sys.path.append('/Users/zero/xgboost/python-package')
import xgboost as xgb
import lightgbm as lgb

from sklearn.model_selection import GridSearchCV
from sklearn.cross_validation import KFold
from sklearn.metrics import log_loss
# Out:
# /usr/local/anaconda3/lib/python3.5/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
y_tr = list(train.is_trade_x)
y_val = list(val.is_trade_x)

# %%
#train/val
params = {
    'objective': 'binary:logistic',
    'eta': 0.06,
    'colsample_bytree': 0.886,
    'min_child_weight': 1.6,
    'max_depth': 4,
    'subsample': 0.886,
    'gamma': 0.1,
    'lambda': 10,
    'verbose_eval': True,
    'eval_metric': 'auc',
    'seed': 201803,
    'missing': -1
}

len(predictors)

xgbtrain = xgb.DMatrix(train[predictors], y_tr)
xgbval = xgb.DMatrix(val[predictors])
model = xgb.train(params, xgbtrain, num_boost_round=450)
y_pred = model.predict(xgbval)
y_pred = pd.Series(y_pred, name='val')

print(log_loss(y_val, y_pred))
# 0.0789725739841 0.06 * 450
# Out:
# 450
# 0.0789725739841

# %%
#cv
params = {
    'objective': 'binary:logistic',
    'eta': 0.01,
    'colsample_bytree': 0.886,
    'min_child_weight': 1.6,
    'max_depth': 4,
    'subsample': 0.886,
    'gamma': 0.1,
    'lambda': 10,
    'verbose_eval': True,
    'eval_metric': 'logloss',
    'seed': 201803,
    'missing': -1
}

len(predictors)

cv_train = pd.concat([train, val])
xgbtrain = xgb.DMatrix(cv_train[predictors], y_tr + y_val)

cv = xgb.cv(
    params,
    dtrain=xgbtrain,
    num_boost_round=5000,
    nfold=5,
    early_stopping_rounds=50,
    seed=201803)
print(str(cv.shape[0]) + ':' + str(cv.iloc[-1, :]['test-logloss-mean']))
# 319:0.082772 0.06
# 547:0.0827352 0.04
# 1016:0.0826854 0.02
# 2044:0.082673 0.01
# Out:
# 450
# 2044:0.082673

# %%
#train/test
params = {
    'objective': 'binary:logistic',
    'eta': 0.04,
    'colsample_bytree': 0.886,
    'min_child_weight': 1.6,
    'max_depth': 4,
    'subsample': 0.886,
    'gamma': 0.1,
    'lambda': 10,
    'verbose_eval': True,
    'eval_metric': 'auc',
    'seed': 201803,
    'missing': -1
}

predictors = list(set(origin + predictors))
predictors = list(set(predictors) - set(rubbish_features))

train = pd.concat([train, val])
xgbtrain = xgb.DMatrix(train[predictors], train[target])
model = xgb.train(params, xgbtrain, num_boost_round=600)

xgbtest = xgb.DMatrix(test[predictors])
y_pred = model.predict(xgbtest)

idx = test.instance_id.reset_index()
idx['predicted_score'] = y_pred
idx[['instance_id', 'predicted_score']].to_csv(
    'resultWithHistory.txt',
    sep=' ',
    header=['instance_id', 'predicted_score'],
    index=False)
