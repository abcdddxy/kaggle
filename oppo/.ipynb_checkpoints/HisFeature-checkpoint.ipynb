# %%
import numpy as np
import os
import pandas as pd
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt
# import seaborn as sns
import pickle
import time
import gc
from tqdm import tqdm, tqdm_notebook

# %matplotlib inline

#每次可以输出多个变量
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from pylab import rcParams
rcParams['figure.figsize'] = 14, 6

import warnings
warnings.filterwarnings("ignore")

#中文字体
import matplotlib
matplotlib.use('qt4agg')
#指定默认字体
matplotlib.rcParams['font.sans-serif'] = ['SimHei']
matplotlib.rcParams['font.family'] = 'sans-serif'
#解决负号'-'显示为方块的问题
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
train_query = pd.read_csv('./data/new/oppo_round1_train_20180929.txt', names=['prefix', 'query_prediction', 'title', 'tag', 'label'], sep='\t', usecols=['query_prediction'])
val_query = pd.read_csv('./data/new/oppo_round1_vali_20180929.txt', names=['prefix', 'query_prediction', 'title', 'tag', 'label'], sep='\t', usecols=['query_prediction'])
test_query = pd.read_csv('./data/new/oppo_round1_test_A_20180929.txt', names=['prefix', 'query_prediction', 'title', 'tag'], sep='\t', usecols=['query_prediction'])

df_query = pd.concat([train_query, val_query], axis=0)
df_query = pd.concat([df_query, test_query], axis=0)
df_query.reset_index(drop=True, inplace=True)
df_query.columns = ['query_prediction_origin']
df_query.shape
# Out:
# (2100000, 1)

# %%
df = pd.read_csv('./feature/df_preprocess_andtest.csv', encoding='utf-8')
df =  pd.concat([df, df_query], axis=1)

df.shape
# Out:
# (2100000, 16)

# %%
df.prefix = df.prefix.fillna('no_pre')

# %%
# %%time
df['is_first_rate'] = df.apply(lambda x: 1 if x.dict_len != 0 and list(eval(x.query_prediction_origin).keys())[0] == x.title else 0, axis=1)
df['title_equal_prefix'] = df.apply(lambda x: 1 if x.prefix == x.title else 0, axis=1)
df['prefix_in_title'] = df.apply(lambda x: 1 if x.prefix in x.title else 0, axis=1)
df['title_startswith_prefix'] = df.apply(lambda x: 1 if x.title.startswith(x.prefix) else 0, axis=1)
df['title_endswith_prefix'] = df.apply(lambda x: 1 if x.title.endswith(x.prefix) else 0, axis=1)
df['rate_big5'] = df.apply(lambda x: 1 if x.title_rate >= 0.5 else 0, axis=1)
df['title_in_query'] = df.apply(lambda x: 1 if x.title in eval(x.query_prediction) else 0, axis=1)

df['title_rank_in_query'] = df.apply(lambda x: list(eval(x.query_prediction).keys()).index(x.title)+1 if x.title_in_query == 1 else 11, axis=1)
df['title_rank_in_query_origin'] = df.apply(lambda x: list(eval(x.query_prediction_origin).keys()).index(x.title)+1 if x.title_in_query == 1 else 11, axis=1)
df['rank_first_origin_rate'] = df.apply(lambda x: float(list(eval(x.query_prediction_origin).values())[0]) if x.dict_len != 0 else 0.6, axis=1)
df['rank_first_origin_rate_sub'] = df.apply(lambda x: x.title_rate - x.rank_first_origin_rate, axis=1)
# Out:
# Wall time: 13min 31s

# %%
df.shape
df.tail()
# Out:
# (2100000, 27)
#          bayes_label  dict_len  is_max_rate  is_val  label  max_title_rate  \
# 2099995          0.0        10            0      -1    NaN           0.328
# 2099996          0.0         9            0      -1    NaN           0.134
# 2099997          0.0        10            0      -1    NaN           0.239
# 2099998          0.0         9            0      -1    NaN           0.036
# 2099999          0.0        10            0      -1    NaN           0.057
#
#         prefix                                   query_prediction tag  \
# 2099995     中通  {'中通快递单号查询': '0.328', '中通快递': '0.187', '中通快递查询...  知道
# 2099996     亚美  {'亚美科技': '0.134', '亚美科技车智汇怎么样': '0.100', '亚美尼亚...  百科
# 2099997   淋巴细胞  {'淋巴细胞百分比偏高': '0.239', '淋巴细胞百分比偏低': '0.085', '...  健康
# 2099998     苹果  {'苹果x': '0.036', '苹果官网': '0.032', '苹果8': '0.02...  经验
# 2099999     地瓜  {'地瓜叶的功效与作用': '0.057', '地瓜图片': '0.045', '地瓜叶子怎...  菜谱
#
#                     title  title_rate  title_rate_max_sub  \
# 2099995  中通快递单号查询那个数字开头最快       0.000               0.328
# 2099996                亚美       0.000               0.134
# 2099997             淋巴细胞高       0.065               0.174
# 2099998    苹果手机怎么关闭系统更新提示       0.000               0.036
# 2099999            地瓜饼的做法       0.018               0.039
#
#                    title_tag                           user_id  \
# 2099995  中通快递单号查询那个数字开头最快_知道  11cdf612623c1ac1073e36b32f83b084
# 2099996                亚美_百科  b25b254cad6d5a69dbdbd115f5178bdc
# 2099997             淋巴细胞高_健康  d1bb946ee46d52bf6ada187f4297b8cb
# 2099998    苹果手机怎么关闭系统更新提示_经验  a3b18e4ddb68015ba6d276784eec8de5
# 2099999            地瓜饼的做法_菜谱  33c23a029e15fd69119fab48ef8f43b9
#
#                                   item_id  \
# 2099995  99fa77afb3130eace45775f21d3ebef9
# 2099996  c3f982ad256ca1c65f85d98db78daba5
# 2099997  f1f671998c31b4178460988cc0d82705
# 2099998  7f21cd8bd3738f24e5fed4d1ff853bc0
# 2099999  55734d907484533b107b14f052b4cd69
#
#                                    query_prediction_origin  is_first_rate  \
# 2099995  {"中通快递电话": "0.019", "中通快递查询": "0.167", "中通快递查询...              0
# 2099996  {"亚美科技": "0.134", "亚美车智汇": "0.060", "亚美车智汇是传销吗...              0
# 2099997  {"淋巴细胞比率偏高": "0.025", "淋巴细胞比率高": "0.018", "淋巴细...              0
# 2099998  {"苹果手机": "0.017", "苹果8plus": "0.022", "苹果9什么时候...              0
# 2099999  {"地瓜图片": "0.045", "地瓜叶": "0.030", "地瓜叶子怎么做好吃":...              0
#
#          title_equal_prefix  prefix_in_title  title_startswith_prefix  \
# 2099995                   0                1                        1
# 2099996                   1                1                        1
# 2099997                   0                1                        1
# 2099998                   0                1                        1
# 2099999                   0                1                        1
#
#          title_endswith_prefix  rate_big5  title_in_query  \
# 2099995                      0          0               0
# 2099996                      1          0               0
# 2099997                      0          0               1
# 2099998                      0          0               0
# 2099999                      0          0               1
#
#          title_rank_in_query  title_rank_in_query_origin  \
# 2099995                   11                          11
# 2099996                   11                          11
# 2099997                    4                          10
# 2099998                   11                          11
# 2099999                    6                          10
#
#          rank_first_origin_rate  rank_first_origin_rate_sub
# 2099995                   0.019                      -0.019
# 2099996                   0.134                      -0.134
# 2099997                   0.025                       0.040
# 2099998                   0.017                      -0.017
# 2099999                   0.045                      -0.027

# %% [markdown]
# ## his

# %%
df = pd.read_csv('./feature/df_feature2.csv', encoding='utf-8')

# %%
from sklearn.cross_validation import train_test_split
# Out:
# C:\Users\ZERO\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
his, train, y_his, y_train = train_test_split(df[df.is_val == 0], df[df.is_val == 0].label, test_size=0.33, random_state=2018)
his.reset_index(drop=True, inplace=True)
train.reset_index(drop=True, inplace=True)

# %%
train = pd.concat([train, df[df.is_val == 1]], axis=0)
train = pd.concat([train, df[df.is_val == -1]], axis=0)

# %%
his.shape
train.shape
# Out:
# (1000000, 27)
# (1100000, 27)

# %% [markdown]
# ## ctr

# %%
items = ['prefix', 'title', 'tag']

for item in tqdm_notebook(items):
    temp = his.groupby(item, as_index = False)['label'].agg({item + '_click':'sum', item + '_ctr':'mean', item + '_count':'count'})
    train = pd.merge(train, temp, on=item, how='left')
    
for i in tqdm_notebook(range(len(items))):
    for j in range(i + 1, len(items)):
        item_g = [items[i], items[j]]
        temp = his.groupby(item_g, as_index=False)['label'].agg({'_'.join(item_g) + '_click': 'sum', '_'.join(item_g) + '_ctr': 'mean', '_'.join(item_g) + '_count':'count'})
        train = pd.merge(train, temp, on=item_g, how='left')
# Out:
# A Jupyter Widget
# A Jupyter Widget

# %% [markdown]
# ## 额外特征

# %%
# df = pd.read_csv('./feature/df_feature3_ctr.csv', encoding='utf-8')

train.shape
# Out:
# (1100000, 45)

# %%
his['prefix_len'] = his.prefix.apply(len)
train['prefix_len'] = train.prefix.apply(len)

# %%
items = ['prefix_len','dict_len','is_max_rate','is_first_rate','title_equal_prefix','prefix_in_title','title_startswith_prefix','title_endswith_prefix','rate_big5','title_in_query','title_rank_in_query','title_rank_in_query_origin']

for item in tqdm_notebook(items):
    temp = his.groupby(item, as_index=False)['label'].agg({item + '_click': 'sum', item + '_ctr': 'mean', item + '_count':'count'})
    train = pd.merge(train, temp, on=item, how='left')

for i in tqdm_notebook(range(len(items))):
    item_g = [items[i], 'tag']
    temp = his.groupby(item_g, as_index=False)['label'].agg({'_'.join(item_g) + '_click': 'sum', '_'.join(item_g) + '_ctr': 'mean', '_'.join(item_g) + '_count':'count'})
    train = pd.merge(train, temp, on=item_g, how='left')
# Out:
# A Jupyter Widget
# A Jupyter Widget

# %%
train.shape
# Out:
# (1100000, 118)

# %%
train.head()
# Out:
#    bayes_label  dict_len  is_max_rate  is_val  label  max_title_rate prefix  \
# 0     0.333333        10            0       0    1.0           0.205    纹身贴
# 1     0.345515        10            1       0    0.0           0.578    今日头
# 2     0.849057        10            0       0    1.0           0.260   深圳地铁
# 3     1.000000        10            0       0    1.0           0.079   火线精英
# 4     0.142857        10            0       0    0.0           0.235    etc
#
#                                     query_prediction tag     title  \
# 0  {'纹身贴怎么洗掉': '0.205', '纹身贴怎么贴': '0.141', '纹身贴图片...  健康  去掉身上的纹身贴
# 1  {'今日头条': '0.578', '今日头条下载': '0.055', '今日头条新闻':...  应用      今日头条
# 2  {'深圳地铁图': '0.260', '深圳地铁线路图': '0.155', '深圳地铁线路...  知道   深圳地铁线路图
# 3  {'火线精英破解版': '0.079', '火线精英好号和密码': '0.034', '火线...  百科      火线精英
# 4  {'etc怎么办理': '0.235', 'etc是什么': '0.184', 'etc充值...  应用     ETC车宝
#
#    title_rate  title_rate_max_sub    title_tag  \
# 0       0.000               0.205  去掉身上的纹身贴_健康
# 1       0.578               0.000      今日头条_应用
# 2       0.155               0.105   深圳地铁线路图_知道
# 3       0.000               0.079      火线精英_百科
# 4       0.000               0.235     ETC车宝_应用
#
#                             user_id                           item_id  \
# 0  bd5a7362412f10ecf7e0a2e334af67f2  48e1641200b234c9f4ae5e3f4320a235
# 1  8c8a4bc1ba2fb9c184f46f6d68c01d22  70e7a194b948c7bcc36faca214942a77
# 2  9eb3942b5e77509c95883c02980854a2  bb6e20ab49ee2d502cd24a2dbbe9b723
# 3  4054d0bbaac704e122e73ecf42f07f04  0cca820e925e20a1deb600fea70f3968
# 4  30779dd93264187f38df836c659ef872  dfdbb4e2a139dc54c3c6c644867ac647
#
#                              query_prediction_origin  is_first_rate  \
# 0  {"纹身贴图片": "0.067", "纹身贴纸": "0.034", "纹身贴怎么用": ...              0
# 1  {"今日头条怎么赚钱": "0.017", "今日头条下载安装": "0.041", "今日...              0
# 2  {"深圳地铁线路图高清": "0.009", "深圳地铁图": "0.260", "深圳地铁...              0
# 3  {"火线精英破解版下载": "0.010", "火线精英好号和密码": "0.034", "...              0
# 4  {"etc是什么": "0.184", "etc如何办理": "0.009", "etc什么...              0
#
#    title_equal_prefix  prefix_in_title  title_startswith_prefix  \
# 0                   0                1                        0
# 1                   0                1                        1
# 2                   0                1                        1
# 3                   1                1                        1
# 4                   0                0                        0
#
#    title_endswith_prefix  rate_big5  title_in_query  title_rank_in_query  \
# 0                      1          0               0                   11
# 1                      0          1               1                    1
# 2                      0          0               1                    2
# 3                      1          0               0                   11
# 4                      0          0               0                   11
#
#    title_rank_in_query_origin  rank_first_origin_rate  \
# 0                          11                   0.067
# 1                           7                   0.017
# 2                           7                   0.009
# 3                          11                   0.010
# 4                          11                   0.184
#
#    rank_first_origin_rate_sub  prefix_click  prefix_ctr  prefix_count  \
# 0                      -0.067           0.0    0.000000           2.0
# 1                       0.561          13.0    0.295455          44.0
# 2                       0.146          49.0    0.355072         138.0
# 3                      -0.010           2.0    0.400000           5.0
# 4                      -0.184           5.0    0.263158          19.0
#
#    title_click  title_ctr  title_count  tag_click   tag_ctr  tag_count  \
# 0          0.0   0.000000          1.0    20798.0  0.297748      69851
# 1        142.0   0.365039        389.0    58244.0  0.352947     165022
# 2         41.0   0.803922         51.0    16260.0  0.247398      65724
# 3          0.0   0.000000          2.0   143309.0  0.396571     361370
# 4          1.0   0.125000          8.0    58244.0  0.352947     165022
#
#    prefix_title_click  prefix_title_ctr  prefix_title_count  prefix_tag_click  \
# 0                 0.0          0.000000                 1.0               0.0
# 1                10.0          0.333333                30.0               7.0
# 2                38.0          0.791667                48.0              38.0
# 3                 0.0          0.000000                 2.0               NaN
# 4                 1.0          0.166667                 6.0               1.0
#
#    prefix_tag_ctr  prefix_tag_count  title_tag_click  title_tag_ctr  \
# 0        0.000000               1.0              0.0       0.000000
# 1        0.233333              30.0             53.0       0.348684
# 2        0.791667              48.0             41.0       0.803922
# 3             NaN               NaN              NaN            NaN
# 4        0.200000               5.0              1.0       0.142857
#
#    title_tag_count  prefix_len  prefix_len_click  prefix_len_ctr  \
# 0              1.0           3           83584.0        0.369667
# 1            152.0           3           83584.0        0.369667
# 2             51.0           4           62215.0        0.376053
# 3              NaN           4           62215.0        0.376053
# 4              7.0           3           83584.0        0.369667
#
#    prefix_len_count  dict_len_click  dict_len_ctr  dict_len_count  \
# 0            226106        271845.0      0.369376          735957
# 1            226106        271845.0      0.369376          735957
# 2            165442        271845.0      0.369376          735957
# 3            165442        271845.0      0.369376          735957
# 4            226106        271845.0      0.369376          735957
#
#    is_max_rate_click  is_max_rate_ctr  is_max_rate_count  is_first_rate_click  \
# 0           264702.0         0.326391             810997             355604.0
# 1           107446.0         0.568488             189003             355604.0
# 2           264702.0         0.326391             810997             355604.0
# 3           264702.0         0.326391             810997             355604.0
# 4           264702.0         0.326391             810997             355604.0
#
#    is_first_rate_ctr  is_first_rate_count  title_equal_prefix_click  \
# 0           0.366546               970149                  290280.0
# 1           0.366546               970149                  290280.0
# 2           0.366546               970149                  290280.0
# 3           0.366546               970149                   81868.0
# 4           0.366546               970149                  290280.0
#
#    title_equal_prefix_ctr  title_equal_prefix_count  prefix_in_title_click  \
# 0                0.359449                    807569               356665.0
# 1                0.359449                    807569               356665.0
# 2                0.359449                    807569               356665.0
# 3                0.425441                    192431               356665.0
# 4                0.359449                    807569                15483.0
#
#    prefix_in_title_ctr  prefix_in_title_count  title_startswith_prefix_click  \
# 0             0.385214                 925887                        68530.0
# 1             0.385214                 925887                       303618.0
# 2             0.385214                 925887                       303618.0
# 3             0.385214                 925887                       303618.0
# 4             0.208911                  74113                        68530.0
#
#    title_startswith_prefix_ctr  title_startswith_prefix_count  \
# 0                     0.253384                         270459
# 1                     0.416177                         729541
# 2                     0.416177                         729541
# 3                     0.416177                         729541
# 4                     0.253384                         270459
#
#    title_endswith_prefix_click  title_endswith_prefix_ctr  \
# 0                     100954.0                   0.375868
# 1                     271194.0                   0.370782
# 2                     271194.0                   0.370782
# 3                     100954.0                   0.375868
# 4                     271194.0                   0.370782
#
#    title_endswith_prefix_count  rate_big5_click  rate_big5_ctr  \
# 0                       268589         351327.0       0.362950
# 1                       731411          20821.0       0.650148
# 2                       731411         351327.0       0.362950
# 3                       268589         351327.0       0.362950
# 4                       731411         351327.0       0.362950
#
#    rate_big5_count  title_in_query_click  title_in_query_ctr  \
# 0           967975              220923.0            0.310027
# 1            32025              151225.0            0.526168
# 2           967975              151225.0            0.526168
# 3           967975              220923.0            0.310027
# 4           967975              220923.0            0.310027
#
#    title_in_query_count  title_rank_in_query_click  title_rank_in_query_ctr  \
# 0                712592                   220923.0                 0.310027
# 1                287408                   106823.0                 0.568002
# 2                287408                    17200.0                 0.508906
# 3                712592                   220923.0                 0.310027
# 4                712592                   220923.0                 0.310027
#
#    title_rank_in_query_count  title_rank_in_query_origin_click  \
# 0                     712592                          220923.0
# 1                     188068                           14758.0
# 2                      33798                           14758.0
# 3                     712592                          220923.0
# 4                     712592                          220923.0
#
#    title_rank_in_query_origin_ctr  title_rank_in_query_origin_count  \
# 0                        0.310027                            712592
# 1                        0.532664                             27706
# 2                        0.532664                             27706
# 3                        0.310027                            712592
# 4                        0.310027                            712592
#
#    prefix_len_tag_click  prefix_len_tag_ctr  prefix_len_tag_count  \
# 0                5503.0            0.283689               19398.0
# 1                8531.0            0.370849               23004.0
# 2                3003.0            0.247425               12137.0
# 3               23973.0            0.377403               63521.0
# 4                8531.0            0.370849               23004.0
#
#    dict_len_tag_click  dict_len_tag_ctr  dict_len_tag_count  \
# 0             14688.0          0.286372             51290.0
# 1             38625.0          0.345764            111709.0
# 2             13106.0          0.249443             52541.0
# 3            104814.0          0.389608            269024.0
# 4             38625.0          0.345764            111709.0
#
#    is_max_rate_tag_click  is_max_rate_tag_ctr  is_max_rate_tag_count  \
# 0                13699.0             0.257113                  53280
# 1                12233.0             0.619142                  19758
# 2                15150.0             0.235307                  64384
# 3                88808.0             0.331897                 267577
# 4                46011.0             0.316741                 145264
#
#    is_first_rate_tag_click  is_first_rate_tag_ctr  is_first_rate_tag_count  \
# 0                  19610.0               0.290924                    67406
# 1                  55167.0               0.343046                   160815
# 2                  16093.0               0.246323                    65333
# 3                 135889.0               0.391377                   347207
# 4                  55167.0               0.343046                   160815
#
#    title_equal_prefix_tag_click  title_equal_prefix_tag_ctr  \
# 0                       19900.0                    0.309251
# 1                       46664.0                    0.322492
# 2                       16243.0                    0.247456
# 3                       51260.0                    0.415704
# 4                       46664.0                    0.322492
#
#    title_equal_prefix_tag_count  prefix_in_title_tag_click  \
# 0                         64349                    20658.0
# 1                        144698                    50856.0
# 2                         65640                    15956.0
# 3                        123309                   140668.0
# 4                        144698                     7388.0
#
#    prefix_in_title_tag_ctr  prefix_in_title_tag_count  \
# 0                 0.297764                      69377
# 1                 0.450959                     112773
# 2                 0.246193                      64811
# 3                 0.397505                     353877
# 4                 0.141400                      52249
#
#    title_startswith_prefix_tag_click  title_startswith_prefix_tag_ctr  \
# 0                             3859.0                         0.190342
# 1                            42576.0                         0.463180
# 2                            10732.0                         0.292784
# 3                           128054.0                         0.430169
# 4                            15668.0                         0.214334
#
#    title_startswith_prefix_tag_count  title_endswith_prefix_tag_click  \
# 0                              20274                           2257.0
# 1                              91921                          41129.0
# 2                              36655                          15414.0
# 3                             297683                          58609.0
# 4                              73101                          41129.0
#
#    title_endswith_prefix_tag_ctr  title_endswith_prefix_tag_count  \
# 0                       0.160893                            14028
# 1                       0.311730                           131938
# 2                       0.251949                            61179
# 3                       0.369922                           158436
# 4                       0.311730                           131938
#
#    rate_big5_tag_click  rate_big5_tag_ctr  rate_big5_tag_count  \
# 0              19049.0           0.285841                66642
# 1               1498.0           0.751254                 1994
# 2              16211.0           0.246867                65667
# 3             131615.0           0.382712               343901
# 4              56746.0           0.348075               163028
#
#    title_in_query_tag_click  title_in_query_tag_ctr  title_in_query_tag_count  \
# 0                   11670.0                0.239532                     48720
# 1                   22003.0                0.533626                     41233
# 2                    2251.0                0.588959                      3822
# 3                   76709.0                0.324481                    236405
# 4                   36241.0                0.292764                    123789
#
#    title_rank_in_query_tag_click  title_rank_in_query_tag_ctr  \
# 0                        11670.0                     0.239532
# 1                        12230.0                     0.619554
# 2                          346.0                     0.614565
# 3                        76709.0                     0.324481
# 4                        36241.0                     0.292764
#
#    title_rank_in_query_tag_count  title_rank_in_query_origin_tag_click  \
# 0                        48720.0                               11670.0
# 1                        19740.0                                1691.0
# 2                          563.0                                 160.0
# 3                       236405.0                               76709.0
# 4                       123789.0                               36241.0
#
#    title_rank_in_query_origin_tag_ctr  title_rank_in_query_origin_tag_count
# 0                            0.239532                               48720.0
# 1                            0.585932                                2886.0
# 2                            0.680851                                 235.0
# 3                            0.324481                              236405.0
# 4                            0.292764                              123789.0

# %%
train.to_csv('./feature/train_feature4_ctr_extra(33).csv', index=None, encoding='utf-8')
